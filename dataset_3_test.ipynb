# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    
    model = YOLO("./runs/detect/animals_dataset_3/weights/best.pt")
    results = model.val(
    data="data_3.yaml",
    split="test",
    name="animals_dataset_3_test",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26n summary (fused): 122 layers, 2,378,736 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access  (ping: 0.00.1 ms, read: 375.2216.8 MB/s, size: 282.0 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\3\labels\test... 319 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 319/319 3.1Kit/s 0.1s<0.0s
# val: New cache created: C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\3\labels\test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 14.3it/s 1.4s0.1s
#                    all        319        358      0.871      0.733      0.818      0.698
#             Brown bear         11         12      0.852      0.833      0.829      0.806
#                 Canary         12         13      0.915      0.923      0.925      0.843
#                Cheetah         14         15      0.623      0.662      0.528      0.501
#              Crocodile         11         11      0.911      0.935      0.988      0.767
#               Elephant         16         21      0.984      0.857      0.924      0.828
#                    Fox         15         15      0.905        0.6      0.877      0.828
#                   Goat         21         22      0.923      0.542      0.803      0.684
#               Goldfish         14         18          1      0.826      0.879      0.666
#               Kangaroo         15         17      0.757      0.647      0.692      0.558
#                Leopard         13         13      0.551      0.385      0.517      0.458
#                  Mouse         16         16      0.776      0.375      0.539      0.279
#                Ostrich         14         17          1      0.934      0.978      0.806
#                  Panda         12         12      0.824      0.784      0.798      0.741
#                    Pig         20         22      0.743      0.727      0.784      0.736
#                 Rabbit         22         23      0.863      0.652      0.855      0.709
#                Raccoon         16         17          1      0.637      0.873      0.653
#             Rhinoceros         22         25          1      0.838      0.906      0.827
#                  Sheep         18         27      0.871      0.741       0.85      0.669
#             Woodpecker         18         19      0.941      0.895      0.918      0.765
#                  Zebra         19         23      0.981       0.87      0.907      0.828
# Speed: 0.5ms preprocess, 1.3ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\runs\detect\animals_dataset_3_test
