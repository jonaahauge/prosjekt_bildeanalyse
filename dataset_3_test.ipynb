# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    ### loading of best model from traning   
    model = YOLO("./runs/detect/animals_dataset_3/weights/best.pt")

    ### runing model validation on testing split
    results = model.val(
    data="data_3.yaml",
    split="test",
    name="animals_dataset_3_test",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26s summary (fused): 122 layers, 9,472,920 parameters, 0 gradients, 20.6 GFLOPs
# val: Fast image access  (ping: 0.10.1 ms, read: 461.5135.8 MB/s, size: 237.4 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\3\labels\test.cache... 319 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 319/319 78.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 13.9it/s 1.4s0.1s
#                    all        319        358      0.843       0.75      0.824      0.713
#             Brown bear         11         12      0.901      0.833      0.906      0.887
#                 Canary         12         13      0.916      0.923      0.925      0.873
#                Cheetah         14         15      0.591      0.733      0.589      0.576
# ...
