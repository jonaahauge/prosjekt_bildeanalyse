# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    
    model = YOLO("./runs/detect/animals_dataset_1/weights/best.pt")
    results = model.val(
    data="data_1.yaml",
    split="val",
    name="animals_dataset_1_val",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26s summary (fused): 122 layers, 9,472,920 parameters, 0 gradients, 20.6 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 1262.2618.9 MB/s, size: 261.0 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\1\labels\val.cache... 459 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 459/459 3.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 13.3it/s 2.2s0.1s
#                    all        459        515      0.803      0.808      0.837      0.725
#             Brown bear         17         18      0.818      0.889      0.917      0.882
#                 Canary         17         20      0.951        0.9       0.94       0.82
#                Cheetah         20         22      0.471      0.609      0.519      0.474
# ...
