# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    
    model = YOLO("./runs/detect/animals_dataset_3/weights/best.pt")
    results = model.val(
    data="data_3.yaml",
    split="val",
    name="animals_dataset_3_val",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26s summary (fused): 122 layers, 9,472,920 parameters, 0 gradients, 20.6 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 1248.1985.3 MB/s, size: 328.0 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\3\labels\val.cache... 459 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 459/459 137.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 13.8it/s 2.1s0.1s
#                    all        459        514      0.788      0.817      0.829      0.698
#             Brown bear         17         18      0.772      0.778      0.738      0.678
#                 Canary         17         18      0.764          1      0.995      0.745
#                Cheetah         20         20       0.45        0.6      0.386      0.349
#              Crocodile         17         17      0.888      0.932      0.983      0.852
#               Elephant         23         24      0.874          1      0.978      0.842
#                    Fox         23         24      0.803      0.792      0.804      0.719
#                   Goat         30         35      0.674      0.886      0.848      0.728
#               Goldfish         20         23      0.882      0.739      0.844      0.595
#               Kangaroo         21         23      0.723       0.87      0.875       0.75
#                Leopard         18         18      0.586       0.55       0.48      0.458
#                  Mouse         22         23      0.668      0.525      0.546      0.362
#                Ostrich         21         21      0.876          1      0.952      0.785
#                  Panda         16         16       0.87      0.812      0.916      0.786
#                    Pig         28         32      0.708      0.757      0.835      0.788
#                 Rabbit         33         36      0.788      0.778      0.851      0.782
#                Raccoon         23         25      0.838       0.84       0.85      0.695
#             Rhinoceros         32         36       0.86      0.856      0.925      0.907
#                  Sheep         26         40      0.852      0.718      0.834      0.539
#             Woodpecker         25         25      0.952       0.96       0.97      0.747
#                  Zebra         27         40       0.93       0.95      0.968      0.858
# Speed: 0.5ms preprocess, 1.8ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\runs\detect\animals_dataset_3_val
