# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    
    model = YOLO("./runs/detect/animals_dataset_3/weights/best.pt")
    results = model.val(
    data="data_3.yaml",
    split="val",
    name="animals_dataset_3_val",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26n summary (fused): 122 layers, 2,378,736 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 1194.91224.3 MB/s, size: 251.2 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\3\labels\val.cache... 459 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 459/459 113.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 15.7it/s 1.8s0.1s
#                    all        459        514      0.818       0.78       0.83      0.696
#             Brown bear         17         18      0.795      0.649       0.82      0.717
#                 Canary         17         18      0.963      0.944      0.945      0.794
#                Cheetah         20         20      0.566       0.75       0.56      0.504
# ...
