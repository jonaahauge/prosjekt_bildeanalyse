# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    
    model = YOLO("./runs/detect/animals_dataset_2/weights/best.pt")
    results = model.val(
    data="data_2.yaml",
    split="test",
    name="animals_dataset_2_test",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26n summary (fused): 122 layers, 2,378,736 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 556.4232.5 MB/s, size: 362.7 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\1\labels\val.cache... 459 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 459/459 107.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 16.9it/s 1.7s0.1s
#                    all        459        515      0.836      0.769      0.814      0.696
#             Brown bear         17         18       0.83      0.778      0.865      0.801
#                 Canary         17         20      0.938       0.85      0.879       0.67
#                Cheetah         20         22      0.569      0.455      0.473      0.384
# ...
