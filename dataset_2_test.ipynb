# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    
    model = YOLO("./runs/detect/animals_dataset_2/weights/best.pt")
    results = model.val(
    data="data_2.yaml",
    split="test",
    name="animals_dataset_2_test",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26s summary (fused): 122 layers, 9,472,920 parameters, 0 gradients, 20.6 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 604.7169.5 MB/s, size: 322.1 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\2\labels\test.cache... 319 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 319/319 102.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 13.6it/s 1.5s0.1s
#                    all        319        365      0.826       0.76      0.811      0.712
#             Brown bear         11         11      0.756          1      0.965      0.947
#                 Canary         12         15          1      0.849       0.93      0.855
#                Cheetah         14         15      0.447        0.6      0.394      0.394
#              Crocodile         11         11      0.958          1      0.995      0.858
#               Elephant         16         18      0.998      0.833      0.835      0.733
#                    Fox         15         15      0.873      0.933      0.985      0.894
#                   Goat         21         23      0.622      0.717      0.612      0.512
#               Goldfish         14         18      0.754      0.778       0.75      0.496
#               Kangaroo         15         20      0.929       0.65      0.763      0.662
#                Leopard         13         13      0.384      0.241      0.418      0.378
#                  Mouse         16         16      0.766        0.5      0.717      0.483
#                Ostrich         14         17          1      0.939      0.945      0.826
#                  Panda         12         12      0.956      0.833      0.898      0.869
#                    Pig         20         32      0.798      0.494      0.739      0.671
#                 Rabbit         22         25      0.738      0.675      0.779      0.683
#                Raccoon         16         17      0.901      0.824      0.935      0.913
#             Rhinoceros         22         23          1      0.949       0.99      0.969
#                  Sheep         18         24      0.748       0.62      0.632      0.449
#             Woodpecker         18         18          1      0.857      0.989        0.8
#                  Zebra         19         22      0.899      0.909      0.942      0.849
# Speed: 0.5ms preprocess, 1.8ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\runs\detect\animals_dataset_2_test
