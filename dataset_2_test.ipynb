# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    
    model = YOLO("./runs/detect/animals_dataset_2/weights/best.pt")
    results = model.val(
    data="data_2.yaml",
    split="test",
    name="animals_dataset_2_test",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26n summary (fused): 122 layers, 2,378,736 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access  (ping: 0.20.2 ms, read: 258.986.0 MB/s, size: 258.4 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\2\labels\test... 319 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 319/319 2.8Kit/s 0.1s<0.0s
# val: New cache created: C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\2\labels\test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 15.0it/s 1.3s0.1s
#                    all        319        365      0.782      0.762      0.801      0.698
#             Brown bear         11         11       0.83      0.887      0.918      0.895
#                 Canary         12         15      0.749      0.733      0.839      0.764
#                Cheetah         14         15      0.444        0.6      0.549      0.541
#              Crocodile         11         11      0.739          1       0.98      0.843
#               Elephant         16         18          1      0.767      0.925      0.879
#                    Fox         15         15      0.699        0.8      0.682      0.619
#                   Goat         21         23      0.618      0.739      0.709      0.572
#               Goldfish         14         18      0.798       0.66      0.642      0.447
#               Kangaroo         15         20      0.976       0.75      0.761      0.698
#                Leopard         13         13      0.538      0.449      0.468      0.426
#                  Mouse         16         16      0.691      0.688       0.82      0.602
#                Ostrich         14         17      0.879      0.824      0.894      0.732
#                  Panda         12         12          1      0.885      0.915      0.885
#                    Pig         20         32       0.74      0.656      0.704      0.619
#                 Rabbit         22         25        0.8       0.72      0.819      0.682
#                Raccoon         16         17      0.877      0.839       0.95      0.867
#             Rhinoceros         22         23       0.87      0.913      0.954      0.929
#                  Sheep         18         24       0.63      0.667      0.597      0.405
#             Woodpecker         18         18      0.911      0.833      0.971      0.698
#                  Zebra         19         22       0.86      0.839      0.925      0.855
# Speed: 0.6ms preprocess, 1.3ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\runs\detect\animals_dataset_2_test
