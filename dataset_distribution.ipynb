# %%
def read_class_label(input_path):
    with open(input, 'r') as f:        
        content = f.readline().strip().split()
        str = ""
        if len(content) == 6:
            str = content[0] + content[1]
        else:
            str = content[0]
        return str
