# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    
    model = YOLO("./runs/detect/animals_dataset_2/weights/best.pt")
    results = model.val(
    data="data_2.yaml",
    split="val",
    name="animals_dataset_2_val",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26s summary (fused): 122 layers, 9,472,920 parameters, 0 gradients, 20.6 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 677.4526.2 MB/s, size: 248.6 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\2\labels\val.cache... 459 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 459/459 1.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 13.4it/s 2.2s0.1s
#                    all        459        527      0.893      0.777      0.844      0.718
#             Brown bear         17         20          1      0.749      0.856      0.782
#                 Canary         17         19      0.886      0.895      0.901      0.838
#                Cheetah         20         20      0.702      0.589      0.543      0.494
# ...
