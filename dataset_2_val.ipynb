# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    
    model = YOLO("./runs/detect/animals_dataset_2/weights/best.pt")
    results = model.val(
    data="data_2.yaml",
    split="val",
    name="animals_dataset_2_val",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26n summary (fused): 122 layers, 2,378,736 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 457.2105.2 MB/s, size: 212.1 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\2\labels\val.cache... 459 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 459/459 137.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 15.7it/s 1.8s0.1s
#                    all        459        527      0.849       0.77      0.826      0.705
#             Brown bear         17         20       0.78        0.8      0.819      0.749
#                 Canary         17         19      0.884      0.801      0.866      0.758
#                Cheetah         20         20      0.559      0.633      0.649      0.606
#              Crocodile         17         18      0.908      0.889      0.933      0.752
#               Elephant         23         25      0.898       0.88      0.897      0.822
#                    Fox         23         24      0.908      0.827      0.891      0.833
#                   Goat         30         38          1      0.699      0.878      0.767
#               Goldfish         20         24      0.838       0.75      0.792       0.58
#               Kangaroo         21         21      0.787      0.905      0.894      0.844
#                Leopard         18         18       0.63      0.758      0.614      0.547
#                  Mouse         22         22      0.696      0.409      0.616       0.38
#                Ostrich         21         24      0.954      0.869      0.867      0.733
#                  Panda         16         16      0.921      0.728      0.841      0.731
#                    Pig         28         34      0.931        0.8      0.843      0.701
#                 Rabbit         33         34      0.718      0.672      0.749      0.613
#                Raccoon         23         24       0.92      0.917      0.974      0.817
#             Rhinoceros         32         43      0.974      0.857      0.957      0.874
#                  Sheep         26         40      0.726       0.45      0.535      0.402
#             Woodpecker         25         28      0.963      0.931      0.962      0.726
#                  Zebra         27         35      0.982      0.829      0.952       0.87
# Speed: 0.5ms preprocess, 1.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\runs\detect\animals_dataset_2_val
