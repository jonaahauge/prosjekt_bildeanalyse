# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    
    model = YOLO("./runs/detect/animals_dataset_1/weights/best.pt")
    results = model.val(
    data="data_1.yaml",
    split="test",
    name="animals_dataset_1_test",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26s summary (fused): 122 layers, 9,472,920 parameters, 0 gradients, 20.6 GFLOPs
# val: Fast image access  (ping: 0.10.1 ms, read: 412.3218.1 MB/s, size: 261.1 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\1\labels\test.cache... 319 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 319/319 525.5Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 12.5it/s 1.6s0.1s
#                    all        319        356      0.849      0.796       0.84      0.727
#             Brown bear         11         11       0.89      0.733      0.901       0.86
#                 Canary         12         12      0.803      0.917      0.937      0.794
#                Cheetah         14         14      0.617      0.857      0.655       0.63
#              Crocodile         11         12      0.906      0.806      0.954      0.682
#               Elephant         16         17          1       0.88      0.929      0.817
#                    Fox         15         16      0.929      0.815      0.897      0.859
#                   Goat         21         24      0.952      0.826      0.855      0.779
#               Goldfish         14         18      0.733      0.611      0.675      0.509
#               Kangaroo         15         17          1      0.765      0.823      0.683
#                Leopard         13         13      0.529      0.462      0.476      0.451
#                  Mouse         16         17       0.73      0.636      0.672      0.432
#                Ostrich         14         16          1      0.802      0.935      0.814
#                  Panda         12         13      0.953      0.769      0.871      0.797
#                    Pig         20         26      0.812      0.833      0.844      0.789
#                 Rabbit         22         25      0.881        0.8      0.941      0.832
#                Raccoon         16         18      0.868      0.944      0.936      0.867
#             Rhinoceros         22         23      0.865          1      0.985      0.929
#                  Sheep         18         20      0.649       0.75      0.697      0.583
#             Woodpecker         18         19      0.956      0.842      0.911       0.69
#                  Zebra         19         25      0.911       0.88      0.915      0.754
# Speed: 0.5ms preprocess, 2.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\runs\detect\animals_dataset_1_test
