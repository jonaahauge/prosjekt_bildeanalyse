# %%
from ultralytics import YOLO

# %%
results = ""
if __name__ == "__main__":
    
    model = YOLO("./runs/detect/animals_dataset_1/weights/best.pt")
    results = model.val(
    data="data_1.yaml",
    split="test",
    name="animals_dataset_1_test",  
    )
# Out:
# Ultralytics 8.4.53  Python-3.14.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26n summary (fused): 122 layers, 2,378,736 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 457.3126.3 MB/s, size: 231.0 KB)
# val: Scanning C:\Users\Jon\Documents\GitHub\prosjekt_bildeanalyse\data\post\1\labels\test.cache... 319 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 319/319 89.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 15.8it/s 1.3s0.1s
#                    all        319        356        0.8      0.738      0.805      0.686
#             Brown bear         11         11      0.725      0.718      0.768      0.751
#                 Canary         12         12      0.924      0.917      0.915      0.843
#                Cheetah         14         14      0.479      0.571      0.537      0.522
# ...
